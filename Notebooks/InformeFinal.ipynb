# %% [markdown]
# # 📄 Informe Final – Evasión de Clientes (Churn) en Telecom X
#
# ## 📊 Resumen del análisis
#
# Durante el análisis exploratorio de los datos proporcionados por Telecom X, se identificaron varios patrones y factores que parecen estar asociados con una mayor probabilidad de que los clientes abandonen la empresa (churn). Los principales hallazgos son los siguientes:
#
# ---
#
# ## 🔍 Principales factores relacionados con la evasión:
#
# ### 📝 1. Tipo de contrato
# - Los clientes con **contrato mensual (Month-to-month)** tienen **una tasa de churn significativamente mayor** en comparación con aquellos que poseen contratos anuales o bianuales.
# - Esto sugiere que la **falta de compromiso a largo plazo** facilita el abandono de la empresa.
#
# ### 🌐 2. Tipo de servicio de Internet
# - Los usuarios que tienen servicio de **Fibra Óptica** son más propensos a dejar la empresa.
# - Esto puede deberse a **problemas de calidad del servicio**, **costo elevado**, o **expectativas no cumplidas**.
#
# ### 💰 3. Gasto mensual y total
# - Los clientes que se dan de baja suelen tener **gastos mensuales más altos**.
# - Sin embargo, su **gasto total tiende a ser bajo**, lo cual indica que **abandonan el servicio rápidamente**, después de solo unos pocos meses.
#
# ### 💳 4. Métodos de pago y facturación
# - La **facturación electrónica (Paperless Billing)** está correlacionada con una mayor evasión.
# - El **pago con cheque electrónico (Electronic Check)** también se asocia con más churn. Podría tratarse de clientes con menor fidelización o menor conocimiento digital.
#
# ### 👤 5. Antigüedad del cliente (tenure)
# - La evasión es más frecuente en clientes con **menos de 12 meses** de antigüedad.
# - Esto indica problemas en la **retención temprana** y posibles fallas en el proceso de bienvenida o en las primeras experiencias con el servicio.
#
# ### 🔐 6. Servicios adicionales
# - La falta de servicios como **seguridad en línea, soporte técnico** o **respaldo en la nube** puede estar influyendo en la decisión de abandonar la empresa.
# - Los clientes que **no contratan estos servicios** suelen mostrar una mayor tasa de churn.
#
# ---
#
# ## 📌 Recomendaciones para el equipo de ciencia de datos
#
# 1. Entrenar modelos predictivos (e.g. Regresión Logística, Random Forest) utilizando las variables:
#     - Tipo de contrato
#     - Método de pago
#     - Servicios adicionales contratados
#     - Tenure
#     - Cargos mensuales y totales
#
# 2. Analizar perfiles de clientes con alta probabilidad de churn y **ofrecer incentivos** para que se mantengan (ej. descuentos o upgrades gratuitos).
#
# 3. Diseñar una estrategia de **retención temprana** para los clientes nuevos, especialmente en los primeros 6 meses.
#
# 4. Explorar más a fondo el motivo detrás del mayor churn en usuarios de fibra óptica mediante encuestas o entrevistas.
#
# ---
#
# ## ✅ Conclusión
#
# El análisis sugiere que la evasión de clientes está fuertemente relacionada con la **falta de contrato a largo plazo**, **altos cargos mensuales**, **servicios incompletos**, y **métodos de pago menos automatizados**. Se recomienda priorizar la **retención de nuevos clientes** y estudiar más a fondo los factores técnicos del servicio de fibra óptica.
